# %%
# %matplotlib inline
from PorousMedium import*
structure_processing(generate_blobs(), 'blobs')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return f(*args, **kwds)
